# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_E0 = pd.read_csv("Synthetic-H/dyn-LL-1/simulations/E0.csv",index_col=0)
df_E0
# Out:
#          E0_1      E0_2      E0_3      E0_4      E0_5      E0_6      E0_7  \
# g1   1.019566  1.109756  1.160085  1.291723  1.287241  1.558812  1.627383
# g2   0.108855  0.149708  0.206109  0.272109  0.239665  0.269185  0.264708
# g3   0.005998  0.005998  0.005998  0.011317  0.014325  0.019879  0.038048
# g4   0.007933  0.031222  0.032529  0.031218  0.044209  0.015380  0.038259
# g5   0.014966  0.000043  0.000043  0.000043  0.000043  0.000043  0.001127
# g6   0.015689  0.008826  0.002216  0.002216  0.005010  0.020667  0.015269
# g7   0.010000  0.010000  0.017214  0.017214  0.018597  0.018382  0.012136
# g8   0.007183  0.028320  0.015661  0.015661  0.022840  0.008545  0.008545
# g9   0.007623  0.007623  0.012701  0.023650  0.027803  0.016199  0.007702
# g10  0.021741  0.035550  0.009299  0.015040  0.015991  0.015991  0.010142
# g11  0.005657  0.005657  0.005657  0.000580  0.000580  0.000580  0.000580
# g12  0.013085  0.024765  0.013092  0.013092  0.010877  0.017663  0.025707
# ...

# %%
plt.plot(df_E0.loc["g1"])
plt.plot(df_E0.loc["g2"])
plt.plot(df_E0.loc["g3"])
plt.plot(df_E0.loc["g4"])
plt.plot(df_E0.loc["g5"])
plt.plot(df_E0.loc["g6"])

# %%
df_E0_per = pd.read_csv("Synthetic-H/dyn-LL-1/simulations_perturbation/E0.csv",index_col=0)
df_E0_per
# Out:
#          E0_1      E0_2      E0_3      E0_4      E0_5      E0_6      E0_7  \
# g1   1.951433  1.945285  1.899404  1.970325  1.880191  2.134161  2.149286
# g2   1.752141  1.562480  1.526763  1.610536  1.489236  1.493063  1.442067
# g3   1.926064  1.788801  1.673828  1.805143  1.876746  1.968866  2.172414
# g4   1.992457  2.374674  2.375710  2.354618  2.458975  2.230928  2.501760
# g5   2.279318  2.085556  1.893946  1.504203  1.431062  1.438683  1.691149
# g6   2.133130  2.057904  1.964446  1.785619  1.892359  2.216948  2.160609
# g7   1.699357  1.584262  1.728967  1.599528  1.669202  1.717549  1.702956
# g8   2.072791  2.436600  2.301671  1.973318  2.074052  1.952103  1.802254
# g9   2.402460  2.072590  2.161449  2.304563  2.338332  2.223460  2.120408
# g10  2.473510  2.596464  2.342688  2.414072  2.403590  2.144183  2.080409
# g11  1.947570  1.834040  1.485337  1.463073  1.462504  1.380725  1.392810
# g12  1.789729  1.960225  1.878107  1.692807  1.706704  1.823652  1.924042
# ...

# %%
plt.plot(df_E0_per.loc["g1"])
plt.plot(df_E0_per.loc["g2"])
plt.plot(df_E0_per.loc["g3"])
plt.plot(df_E0_per.loc["g4"])
plt.plot(df_E0_per.loc["g5"])
plt.plot(df_E0_per.loc["g6"])

# %%
df_E0_per = pd.read_csv("Synthetic-H/dyn-LL-1/simulations_perturbation/E0.csv",index_col=0)
df_E0_per
